# %%
from ingest import load_faq_data, build_index
from rag_helper import RAGHelper, anthropic

# %%
documents = load_faq_data()

# %%
index = build_index(documents)

# %%
assistant = RAGHelper(index, anthropic)

# %%
assistant.rag("Can I join the course?")
# Out:
# "Yes, you can join the course! According to the course information:\n\n- **You can join anytime** - the videos and GitHub materials are available whenever you want to start\n- **You don't need a confirmation email** - if you've registered, you're accepted. You can also start learning and submitting homework without formally registering\n- **You can work at your own pace** - you can go through the material in self-paced mode\n\nHowever, there's an important note about certificates: **If you want to receive a certificate, you need to submit your project while the course is still accepting submissions from a live cohort.** You can prepare the project on your own schedule, but the actual project submission and peer reviews must happen while a live cohort is active.\n\nTo get started, check out the [LLM Zoomcamp docs](https://datatalks.club/docs/courses/llm-zoomcamp/), the [general Zoomcamp logistics docs](https://datatalks.club/docs/courses/zoomcamp-logistics/), and the [LLM Zoomcamp Git
# ...
