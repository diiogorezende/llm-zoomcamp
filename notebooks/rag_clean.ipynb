# %%
from ingest import load_faq_data, build_index
from rag_helper import RAGHelper, anthropic

# %%
documents = load_faq_data()

# %%
index = build_index(documents)

# %%
assistant = RAGHelper(index, anthropic)

# %%
print(assistant.rag("How do I run Ollama locally?"))
# Out:
# # How to Run Ollama Locally
#
# To run Ollama locally, follow these steps:
#
# ## 1. Install Ollama
# Visit [https://ollama.com/download](https://ollama.com/download) and choose your operating system:
#
# - **macOS**: Download the `.pkg` and install it
# - **Windows**: Download the `.msi` and install it
# - **Linux**: Run this command in the terminal:
#   ```bash
#   curl -fsSL https://ollama.com/install.sh | sh
#   ```
#
# ## 2. Start Ollama
# Open a terminal and run:
# ```bash
# ollama run llama3
# ```
#
# This will:
# - Download the LLaMA 3 model (~4GB)
# - Start the model locally
# - Open a chat-like interface where you can type questions
#
# ## 3. Test the Local Server
# Verify Ollama is running by executing:
# ```bash
# curl http://localhost:11434
# ```
#
# You should receive a response with model information in JSON format.
#
# ## 4. Use with Python (Optional)
# If you want to use Ollama in Python code:
#
# ```bash
# pip install ollama
# ```
#
# Then use it like this:
# ```python
# import ollama
#
# response = ollama.chat(
#     model='llama3',
